# %%
from chrisbase.io import BaseProjectEnv
from chrisbase.util import to_dataframe

env = BaseProjectEnv(project_name="DeepKorean")
to_dataframe(env)
# Out:
#             key                                                         value
# 0      hostname                                                     chrisbook
# 1      hostaddr                                                   10.42.0.191
# 2   python_path  /Users/chris/mambaforge/envs/DeepKorean-23.03/bin/python3.10
# 3  project_name                                                    DeepKorean
# 4  project_path                                 /Users/chris/DeepKorean-23.03
# 5  working_path                                 /Users/chris/DeepKorean-23.03
# 6  running_file                                             tests/1-env.ipynb

# %%
from chrisbase.io import environ_to_dataframe

environ_to_dataframe(max_value_len=400)
# Out:
#                         key                                                                                                                                                                                                            value
# 0                  CLICOLOR                                                                                                                                                                                                                1
# 1            CLICOLOR_FORCE                                                                                                                                                                                                                1
# 2              COMMAND_MODE                                                                                                                                                                                                         unix2003
# 3         CONDA_DEFAULT_ENV                                                                                                                                                                                                 DeepKorean-23.03
# 4                 CONDA_EXE                                                                                                                                                                                /Users/chris/mambaforge/bin/conda
# 5              CONDA_PREFIX                                                                                                                                                                    /Users/chris/mambaforge/envs/DeepKorean-23.03
# 6     CONDA_PROMPT_MODIFIER                                                                                                                                                                                              (DeepKorean-23.03)
# 7          CONDA_PYTHON_EXE                                                                                                                                                                               /Users/chris/mambaforge/bin/python
# 8               CONDA_SHLVL                                                                                                                                                                                                                2
# 9               FORCE_COLOR                                                                                                                                                                                                                1
# 10                GIT_PAGER                                                                                                                                                                                                              cat
# 11                     HOME                                                                                                                                                                                                     /Users/chris
# 12          HOMEBREW_CELLAR                                                                                                                                                                                             /opt/homebrew/Cellar
# 13          HOMEBREW_PREFIX                                                                                                                                                                                                    /opt/homebrew
# 14      HOMEBREW_REPOSITORY                                                                                                                                                                                                    /opt/homebrew
# 15                 INFOPATH                                                                                                                                                                                        /opt/homebrew/share/info:
# 16           JPY_PARENT_PID                                                                                                                                                                                                            35281
# 17                     LANG                                                                                                                                                                                                      en_US.UTF-8
# 18                 LANGUAGE
# 19                   LC_ALL                                                                                                                                                                                                      en_US.UTF-8
# 20                 LC_CTYPE                                                                                                                                                                                                      ko_KR.UTF-8
# 21                  LOGNAME                                                                                                                                                                                                            chris
# 22                  MANPATH                                                                                                                                                                                        /opt/homebrew/share/man::
# 23               MPLBACKEND                                                                                                                                                                        module://matplotlib_inline.backend_inline
# 24                   OLDPWD                                                                                                                                                                                                                /
# 25                    PAGER                                                                                                                                                                                                              cat
# 26                     PATH               /Users/chris/mambaforge/envs/DeepKorean-23.03/bin:/Users/chris/mambaforge/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin
# 27                      PWD                                                                                                                                                                                    /Users/chris/DeepKorean-23.03
# 28    PYDEVD_USE_FRAME_EVAL                                                                                                                                                                                                               NO
# 29               PYTHONPATH  /Users/chris/DeepKorean-23.03:/Users/chris/DeepKorean-23.03/chrislab/src:/Users/chris/DeepKorean-23.03/chrisbase/src:/Users/chris/DeepKorean-23.03/transformers/src:/Users/chris/DeepKorean-23.03/lightning/src
# 30                    SHELL                                                                                                                                                                                                         /bin/zsh
# 31            SSH_AUTH_SOCK                                                                                                                                                              /private/tmp/com.apple.launchd.frhgA7tndb/Listeners
# 32                     TERM                                                                                                                                                                                                      xterm-color
# 33                   TMPDIR                                                                                                                                                                /var/folders/fd/7wz82y754nvgy4fcfmmnpf_c0000gn/T/
# 34                     USER                                                                                                                                                                                                            chris
# 35                XPC_FLAGS                                                                                                                                                                                                              0x0
# 36         XPC_SERVICE_NAME                                                                                                                                                                  application.com.jetbrains.pycharm.843177.843848
# 37                _CE_CONDA
# 38                    _CE_M
# 39     __CFBundleIdentifier                                                                                                                                                                                            com.jetbrains.pycharm
# 40  __CF_USER_TEXT_ENCODING                                                                                                                                                                                                   0x1F5:0x3:0x33
